# %% [markdown]
# <a href="https://colab.research.google.com/github/mayank261193/Session-6-Pandas/blob/main/S1_dataframes_and_exploring_solutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # S06 — Practice 1: DataFrames & Exploring
# ### SOLUTIONS

# %% [markdown]
# **Applied AI & Analytics Lab** · Session 6 · Practice notebook 1 of 3
#
# **Time:** about 20 minutes.
# **How to use this:** each exercise has a cell with `____` blanks or a `# YOUR CODE HERE` line. Fill it in and run it. The expected output is in the comment.
#
# > **Setup:** upload `session6_policy_data.csv` and `session6_region_lookup.csv` (folder icon → Upload) before you start.
#
# Do not open the solutions notebook until you have tried every one. Struggling **is** the learning.
#
# ---

# %% [markdown]
# > **Solutions notebook.** Use this only after you have really tried.
# > Reading a solution feels like learning. It is not. Struggling is.

# %%
import pandas as pd
df = pd.read_csv("session6_policy_data.csv")

# %% [markdown]
# ### Exercise 1 — Load and measure  ·  *easy*
#
# The data is already loaded into `df` above. Print its shape (rows, columns).

# %%
print(df.shape)     # (51, 5)
# Out:
# (51, 5)

# %% [markdown]
# ### Exercise 2 — First and last rows  ·  *easy*
#
# Show the first 3 rows, then the last 2 rows.

# %%
display(df.head(3))
display(df.tail(2))
# Out:
#   region  year  employment_rate  budget_million  population
# 0  North  2021             92.3            12.5       50000
# 1  South  2021             88.7            15.2       62000
# 2   East  2021             91.2             9.8       48000
#      region  year  employment_rate  budget_million  population
# 49  Central  2030             95.5            18.5       63500
# 50    North  2021             92.3            12.5       50000

# %% [markdown]
# ### Exercise 3 — The column list  ·  *easy*
#
# Print the column names.

# %%
print(df.columns)   # Index(['region', 'year', 'employment_rate', 'budget_million', 'population'], ...)
# Out:
# Index(['region', 'year', 'employment_rate', 'budget_million', 'population'], dtype='object')

# %% [markdown]
# ### Exercise 4 — Spot the missing data  ·  *medium*
#
# Use `.info()` to see non-null counts, then print how many `budget_million` values are present.

# %%
df.info()
print(df["budget_million"].notna().sum())   # 49 present (2 missing)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   region           51 non-null     object
#  1   year             51 non-null     int64
#  2   employment_rate  51 non-null     float64
#  3   budget_million   49 non-null     float64
#  4   population       51 non-null     int64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 2.1+ KB
# 49

# %% [markdown]
# ### Exercise 5 — Summary statistics  ·  *medium*
#
# Print `.describe()` and read off the largest population.

# %%
print(df.describe())
# The max population is 67400
# Out:
#               year  employment_rate  budget_million    population
# count    51.000000        51.000000       49.000000     51.000000
# mean   2025.411765        92.100000       14.646939  56321.078431
# std       2.940588         2.646205        2.469826   5943.875782
# min    2021.000000        85.400000        9.800000  48000.000000
# 25%    2023.000000        90.650000       12.600000  51012.500000
# 50%    2025.000000        92.400000       14.500000  55000.000000
# 75%    2028.000000        93.950000       16.500000  62000.000000
# max    2030.000000        97.000000       19.500000  67400.000000

# %% [markdown]
# ### Exercise 6 — A column is a Series  ·  *medium*
#
# Pull out the `region` column and confirm its type is a Series.

# %%
regions = df["region"]
print(type(regions))   # <class 'pandas.core.series.Series'>
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ### Exercise 7 — Select two columns  ·  *medium*
#
# Show just `region` and `employment_rate` (double brackets → a DataFrame).

# %%
df[["region", "employment_rate"]].head()
# Out:
#     region  employment_rate
# 0    North             92.3
# 1    South             88.7
# 2     East             91.2
# 3     West             85.4
# 4  Central             90.1

# %% [markdown]
# ### Exercise 8 — Count the rows  ·  *medium*
#
# Print the number of rows using `.shape` (not `len` of the file).

# %%
print(df.shape[0])   # 51
# Out:
# 51

# %% [markdown]
# ### Exercise 9 — A quick average  ·  *hard*
#
# Print the average `employment_rate` across the whole dataset, rounded to 2 dp.

# %%
print(round(df["employment_rate"].mean(), 2))   # about 92.46
# Out:
# 92.1

# %% [markdown]
# ### Exercise 10 — Earliest and latest year  ·  *hard*
#
# Print the minimum and maximum `year` in the data.

# %%
print(df["year"].min(), df["year"].max())   # 2021 2030
# Out:
# 2021 2030

# %% [markdown]
# ---
#
# **Done.** Commit this notebook to your GitHub Session-6 folder with a short note.
